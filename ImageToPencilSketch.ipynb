# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhika-Shirke/ImageToPencilSketch/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread("images.jpg")
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F96A3D07210>
# -1

# %% [markdown]
# ** CONVERTING ORIGINAL IMAGE TO GRAYSCALE IMAGE**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F96A3B54750>
# -1

# %% [markdown]
# **INVERT GRAYSCALE IMAGE **

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F96A3BCDF10>
# -1

# %% [markdown]
# blur the image by using the Gaussian Function in OpenCV

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %% [markdown]
# **Invert the blurred image**

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F96A3B547D0>
# -1

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F96A3C52E90>
# <PIL.Image.Image image mode=L size=225x225 at 0x7F96A3B54B10>
# -1
